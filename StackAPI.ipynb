# %%
import csv
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords

# %%
a = input("text")
r = requests.get('http://api.stackexchange.com/2.2/posts?page=3&pagesize=100&fromdate=1514764800&order=desc&min=1546214400&sort=activity&site=softwarerecs&tagged='+a+'&filter=!9Z(-wtr.v')
x = r.json()
df = pd.DataFrame(x['items'])
dt = df['body_markdown']
# Out:
# textpdf

# %%
x
# Out:
# {'items': [{'owner': {'reputation': 1,
#     'user_id': 47887,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/bEWXG.gif?s=128&g=1',
#     'display_name': 'リカルド',
#     'link': 'https://softwarerecs.stackexchange.com/users/47887/%e3%83%aa%e3%82%ab%e3%83%ab%e3%83%89'},
#    'score': -1,
#    'last_activity_date': 1555261684,
#    'creation_date': 1555261684,
#    'post_type': 'question',
#    'post_id': 58242,
# ...
