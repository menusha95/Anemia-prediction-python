# %%
import random
for x in range(250):
    print(round(random.uniform(11.5,15.9),1))
# Out:
# 11.8
# 14.6
# 12.4
# 12.4
# 13.6
# 13.3
# 13.7
# 14.8
# 11.9
# 12.9
# 15.2
# 13.9
# 13.5
# 11.6
# 13.5
# 14.6
# 13.7
# 12.6
# 15.2
# 15.0
# 15.3
# 15.4
# 14.1
# 15.3
# 15.7
# 14.3
# 13.2
# 11.7
# 14.6
# 11.9
# 15.1
# 13.2
# 13.1
# 14.9
# 12.8
# 13.6
# 13.4
# 12.0
# 12.0
# 15.5
# 13.4
# 15.4
# 14.6
# 13.7
# 13.2
# 14.0
# 14.2
# 14.6
# 14.4
# 14.7
# 11.6
# 14.9
# 13.6
# 14.5
# 15.6
# 15.3
# 13.1
# 14.7
# 13.1
# 15.3
# 14.1
# 12.6
# 11.9
# 15.2
# 12.2
# 13.2
# 11.8
# 15.8
# 13.4
# 15.3
# 14.9
# 13.0
# 15.9
# 11.7
# 11.9
# 13.7
# 15.7
# 12.6
# 14.8
# 12.9
# 14.6
# 15.6
# 13.0
# 14.1
# 12.1
# 15.2
# 13.9
# 14.9
# 15.4
# 15.8
# 13.4
# 14.1
# 12.0
# 11.6
# 12.7
# 14.4
# 12.6
# 13.6
# 14.7
# 12.3
# 12.0
# 15.8
# 14.6
# 14.2
# 14.3
# 11.6
# 12.3
# 12.8
# 13.7
# 13.4
# 14.8
# 15.2
# 12.4
# 15.1
# 11.7
# 13.7
# 12.7
# 15.0
# 13.0
# 12.0
# 12.3
# 12.6
# 11.8
# 14.5
# 13.7
# 13.3
# 15.7
# 11.8
# 14.9
# 15.5
# 15.8
# 14.6
# 12.8
# 12.0
# 12.2
# 14.8
# 12.7
# 13.8
# 14.0
# 13.4
# 11.6
# 14.3
# ...
